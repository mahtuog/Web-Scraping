# %%
import bs4
import urllib
import pandas as pd
import itertools
import numpy as np
import re

# %%
input_url = 'https://www.quora.com/Where-can-I-find-full-data-science-case-studies'

# %%
def scrape_quora(input_url):
    """
    Description :
    Input  - Quora URL 
    Output - Dictionary with question as key and a DataFrame as value.
    DataFrame Contents : 'User_Name','Profile_Link','Occupation','Answered_On','Answer'
    
    Usage Example:
    
    input_url = 'https://www.quora.com/Where-can-I-find-full-data-science-case-studies'
    output = scrape_quora(input_url)
    """
    # scrape the page
    page = urllib.request.urlopen(input_url).read()
    soup = bs4.BeautifulSoup(page,'html.parser')
    question = soup.find('div',{'class':'QuestionArea'}).find('span',{'class':'ui_qtext_rendered_qtext'}).get_text()
        
    all_answers = soup.findAll('div',{'class':'answer_text_small'})    
    # create an empty DataFrame with structure needed.
    df = pd.DataFrame(columns=['User_Name','Profile_Link','Occupation','Answered_On','Answer'])   
    QandA = {}
    #loop through answers one by one and get the info
    for i in all_answers:
        answer_base = i.findAll('div',{'class':'Answer AnswerBase'})
        for j in answer_base:            
            user_info = j.find('div',{'class':'u-margin-right--sm'})
            try:
                user_name = user_info.find('a',{'class':'user'}).get_text()      
            except:
                user_name = 'Anonymous'
            try:
                user_link = 'https://www.quora.com'+user_info.find('a').get('href')
            except:
                user_link = np.nan
            try:
                occupation = user_info.find('span',{'class':'NameCredential'}).get_text()
            except:
                occupation = np.nan
            answered_on = user_info.find('span',{'class':'credibility_wrapper'}).get_text()
            answer = j.find('div',{'class':'ui_qtext_expanded'}).get_text()
            curr_row = {'User_Name': user_name,
                                     'Profile_Link':user_link,
                                     'Occupation':occupation,
                                     'Answered_On':answered_on,
                                     'Answer':answer}
            df = df.append(curr_row,ignore_index=True)
    QandA[input_url] = df
    
    return(QandA)

# %%
def scrape_related_questions(input_url):
    """   
    `
    Input  - Quora URL
    Output - Array with list of related questions.
    
    Usage -
    input_url = 'https://www.quora.com/Where-can-I-find-full-data-science-case-studies'
    output = scrape_related_questions(input_url)
    
    `
    """  
    related_questions = []
    page = urllib.request.urlopen(input_url).read()
    soup = bs4.BeautifulSoup(page,'html.parser')
    all_related_questions = soup.find('div',{'class':'question_related list side_bar'}).find('ul')
    for i in all_related_questions:
        try:
            url = 'https://www.quora.com'+i.find('a').get('href')
            related_questions.append(url)
        except:
            pass
    return(related_questions)

# %%
input_url = 'https://www.quora.com/What-are-the-best-institutes-to-study-data-science-in-chennai'

# %%
master_dictionary = scrape_quora(input_url)
related = scrape_related_questions(input_url)
for i in related:
    if i not in master_dictionary:
        tmp_dic = scrape_quora(i)
        master_dictionary[i] = tmp_dic[i]

# %%
master_df = pd.DataFrame.from_dict(master_dictionary,orient='index',columns=['Scraped_info'])

# %%
master_df.iloc[0]['Scraped_info']
# Out:
#             User_Name                                       Profile_Link  \
# 0       Nisha Serisha        https://www.quora.com/profile/Nisha-Serisha
# 1          Jeyanthi R         https://www.quora.com/profile/Jeyanthi-R-3
# 2   Abhisek Chaudhary  https://www.quora.com/profile/Abhisek-Chaudhary-2
# 3      Satish Trainer       https://www.quora.com/profile/Satish-Trainer
# 4            Suba Sri          https://www.quora.com/profile/Suba-Sri-43
# 5       Sameer Shukla     https://www.quora.com/profile/Sameer-Shukla-42
# 6         Jone Sathya          https://www.quora.com/profile/Jone-Sathya
# 7        Mancy Mathew       https://www.quora.com/profile/Mancy-Mathew-1
# 8           Nila Shri          https://www.quora.com/profile/Nila-Shri-2
# 9       Genesis Sarah        https://www.quora.com/profile/Genesis-Sarah
# 10    Reyansh Agastya      https://www.quora.com/profile/Reyansh-Agastya
# 11      Shalini Priya    https://www.quora.com/profile/Shalini-Priya-110
# 12        Asika Kumar          https://www.quora.com/profile/Asika-Kumar
# 13     Santhosh Kumar  https://www.quora.com/profile/Santhosh-Kumar-2837
# 14          Nivatha V            https://www.quora.com/profile/Nivatha-V
# 15        Kapil Nakra          https://www.quora.com/profile/Kapil-Nakra
# 16       Raghu Gaddam       https://www.quora.com/profile/Raghu-Gaddam-4
# 17              Sofia            https://www.quora.com/profile/Sofia-457
# 18          Saro Saro         https://www.quora.com/profile/Saro-Saro-15
# 19      Sugantha Raja      https://www.quora.com/profile/Sugantha-Raja-1
#
#                                            Occupation  \
# 0               , lives in Chennai, Tamil Nadu, India
# 1                       , Digital marketing Executive
# 2                  , Python Developer  (2014-present)
# 3                                                 NaN
# 4                                                 NaN
# 5   , Career Development Executive at TACT Learn (...
# 6   , Ph.D Computer Science & Software Engineering...
# 7               , Cheif Data Scientist (1997-present)
# 8   , lives in Chennai, Tamil Nadu, India (1995-pr...
# 9                                                 NaN
# 10                                                NaN
# 11  , Digital Marketing Executive at BDreamz Globa...
# 12  , M.S Computer Science, The University of Okla...
# 13                                                NaN
# 14  , former Data Analyst at Tata Consultancy Serv...
# 15                       , Cofounder at Digital Vidya
# 16   , former Digital Marketing & Data Science Expert
# 17                                   , Data Scientist
# 18                              , former Data Analyst
# 19  , lives in Chennai, Tamil Nadu, India (2015-pr...
#
#                                           Answered_On  \
# 0                                Updated Jun 21, 2018
# 1                               Answered Aug 25, 2018
# 2                                Answered Nov 6, 2017
# 3                               Answered Aug 12, 2018
# 4                               Answered Dec 21, 2017
# 5                                Answered Jul 6, 2017
# 6   Answered Aug 24, 2018 · Author has 144 answers...
# 7   Answered Nov 30, 2017 · Author has 67 answers ...
# 8                                 Updated Sep 8, 2018
# 9   Answered Oct 3, 2018 · Author has 69 answers a...
# 10                              Answered Sep 20, 2018
# 11                              Answered Aug 20, 2018
# 12                               Updated Oct 19, 2018
# 13                               Answered May 5, 2018
# 14                               Answered Aug 6, 2018
# 15  Answered Aug 2, 2018 · Author has 614 answers ...
# 16                               Updated Aug 27, 2018
# 17                               Answered Oct 5, 2018
# 18                              Answered Sep 11, 2018
# 19  Answered Sep 6, 2018 · Author has 57 answers a...
#
#                                                Answer
# 0   Ampersand Academy is the best institute to stu...
# 1   Besant technologies is the best place to learn...
# 2   Before Joining any institute,Please read below...
# 3   Hi,This is Satish, working for Citibank as Dat...
# 4   Data Science is the combination of statistics,...
# 5   HiYou can go for online live training from TAC...
# 6   Yep..!Data Science is currently the top trendi...
# 7   Greens Technology provides data analytics and ...
# 8   Besant technologies are the best place to lear...
# 9   Besant Technologies Provides Best Data Science...
# 10  It’s good that you’re interested in learning d...
# 11  Besant technologies are the best institute to ...
# 12  Online classes are more flexible & convenient ...
# 13  Hello,I completed my data science training at ...
# 14  Besant technologies is the best place to learn...
# 15  Best Data Science Institutes in Chennai:Digita...
# 16  Pertaining to Data Science training in Chennai...
# 17  In the recent days in the information technolo...
# 18  According to me, Besant technologies would be ...
# 19  Softlogic Systems Provides Data Science traini...
